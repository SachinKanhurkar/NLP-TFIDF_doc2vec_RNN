# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['', 'picking', 'various', 'points', 'going', ...
# 1  ['dude', 'makin', 'weirdy', 'brownies', 'siste...
# 2                 ['hen', 'night', 'going', 'swing']
# 3  ['hi', '07734396839', 'ibh', 'customer', 'loya...
# 4                  ['love', 'aathilove', 'u', 'lot']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'picking': 5541,
#  'various': 7704,
#  'points': 5632,
#  'going': 3339,
#  'yeovil': 8193,
#  'motor': 4892,
#  'project': 5801,
#  'hours': 3716,
#  'take': 7111,
#  'home': 3670,
#  '12': 287,
#  '530': 614,
#  'max': 4668,
#  'easy': 2672,
#  'dude': 2638,
#  'makin': 4600,
#  'weirdy': 7903,
#  'brownies': 1634,
#  'sister': 6568,
#  'made': 4578,
#  'awesome': 1272,
#  'cookies': 2136,
#  'took': 7408,
#  'pics': 5543,
#  'hen': 3589,
#  'night': 5076,
#  'swing': 7080,
#  'hi': 3613,
#  '07734396839': 26,
#  'ibh': 3793,
#  'customer': 2259,
#  'loyalty': 4511,
#  'offer': 5227,
#  'new': 5053,
#  'nokia6600': 5118,
#  'mobile': 4833,
#  '10': 254,
#  'txtauctiontxt': 7542,
#  'wordstart': 8045,
#  'no81151': 5101,
#  'get': 3281,
#  'now4t': 5161,
#  'love': 4492,
#  'aathilove': 829,
#  'lot': 4478,
#  'well': 7907,
#  'keep': 4140,
#  'mind': 4775,
#  'ive': 3995,
#  'got': 3374,
#  'enough': 2765,
#  'gas': 3242,
#  'one': 5272,
#  'round': 6192,
#  'trip': 7478,
#  'barring': 1335,
#  'sudden': 6987,
#  'influx': 3886,
#  'cash': 1801,
#  'mystery': 4970,
#  'solved': 6687,
#  'opened': 5294,
#  'email': 2728,
#  'hes': 3603,
#  'sent': 6386,
#  'another': 1083,
#  'batch': 1344,
#  'isnt': 3966,
#  'sweetie': 7074,
#  'feel': 2966,
#  'like': 4375,
#  'dick': 2446,
#  'sleeping': 6605,
#  'texts': 7220,
#  'facebook': 2900,
#  'messages': 4744,
#  'sup': 7023,
#  'town': 7441,
#  'jay': 4022,
#  'says': 6296,
#  'hell': 3573,
#  'put': 5860,
#  'ltgt': 4522,
#  'shall': 6433,
#  'come': 2035,
#  'pickle': 5542,
#  'yes': 8196,
#  'princess': 5760,
#  'want': 7825,
#  'please': 5596,
#  'every': 2824,
#  'wish': 7995,
#  'command': 2046,
#  'check': 1885,
#  'detailed': 2421,
#  'message': 4738,
#  'honey': 3681,
#  'pls': 5603,
#  'find': 3011,
#  'much': 4930,
#  'sell': 6371,
#  'predicte': 5724,
#  'nigeria': 5074,
#  'many': 4622,
#  'times': 7334,
#  'used': 7665,
#  'important': 3844,
#  'reply': 6076,
#  'monday': 4858,
#  'geeeee': 3262,
#  'barely': 1329,
#  'stand': 6844,
#  'dont': 2563,
#  'think': 7273,
#  'need': 5025,
#  'late': 4284,
#  'school': 6308,
#  'especially': 2798,
#  'class': 1963,
#  'missed': 4803,
#  'last': 4281,
#  'wednesday': 7885,
#  'probably': 5776,
#  'failed': 2908,
#  'test': 7205,
#  'friday': 3162,
#  'unique': 7602,
#  '30th': 490,
#  'august': 1241,
#  'wwwareyouuniquecouk': 8105,
#  'usualiam': 7679,
#  'fine': 3012,
#  'happy': 3519,
#  'amp': 1050,
#  '0anetworks': 253,
#  'allow': 1015,
#  'companies': 2052,
#  'bill': 1449,
#  'sms': 6653,
#  'responsible': 6107,
#  'suppliers': 7030,
#  'sac': 6237,
#  'needs': 5029,
#  'carry': 1794,
#  'girl': 3302,
#  'propose': 5818,
#  'today': 7369,
#  'seing': 6363,
#  'ur': 7647,
#  'bloody': 1501,
#  'funky': 3208,
#  'shit': 6468,
#  'fucking': 3192,
#  'faceasssssholeeee': 2899,
#  'storming': 6923,
#  'msg': 4913,
#  'wen': 7911,
#  'lift': 4369,
#  'phne': 5525,
#  'say': 6294,
#  'hello': 3575,
#  'knw': 4216,
#  'wt': 8092,
#  'real': 5952,
#  'meaning': 4684,
#  'name': 4983,
#  'dat': 2306,
#  'margaret': 4630,
#  'girlfrnd': 3304,
#  'grahmbell': 3394,
#  'invnted': 3940,
#  'telphone': 7182,
#  'moralone': 4877,
#  '4get': 580,
#  'person': 5500,
#  'blackberry': 1473,
#  'bold2': 1520,
#  'ìï': 8275,
#  'called': 1726,
#  'dad': 2277,
#  'oredi': 5322,
#  'call': 1711,
#  'germany': 3280,
#  'pence': 5477,
#  'per': 5485,
#  'minute': 4792,
#  'fixed': 3037,
#  'line': 4388,
#  'via': 7727,
#  'access': 859,
#  'number': 5185,
#  '0844': 55,
#  '861': 766,
#  '85': 758,
#  'prepayment': 5735,
#  'direct': 2485,
#  'wwwtelediscountcouk': 8137,
#  'die': 2454,
#  'accidentally': 863,
#  'deleted': 2381,
#  'suppose': 7037,
#  'sim': 6545,
#  'archive': 1152,
#  'haiz': 3486,
#  'sad': 6242,
#  'know': 4210,
#  'oh': 5245,
#  'sending': 6380,
#  'greetings': 3420,
#  'joy': 4084,
#  'happiness': 3518,
#  'gr8': 3388,
#  'evening': 2818,
#  'hurt': 3778,
#  'tease': 7166,
#  'make': 4597,
#  'cry': 2224,
#  'end': 2743,
#  'life': 4364,
#  'plz': 5609,
#  'rose': 6189,
#  'grave': 3405,
#  'stupid': 6962,
#  'miss': 4801,
#  'nice': 5068,
#  'day': 2319,
#  'bslvyl': 1639,
#  'innocent': 3906,
#  'fun': 3201,
#  'beautiful': 1377,
#  'truth': 7496,
#  'gravity': 3407,
#  'read': 5946,
#  'carefully': 1779,
#  'heart': 3557,
#  'feels': 2970,
#  'light': 4372,
#  'someone': 6691,
#  'heavy': 3565,
#  'leaves': 4321,
#  'goodmorning': 3359,
#  'coming': 2043,
#  'leave': 4320,
#  'pongaldo': 5649,
#  'news': 5058,
#  'work': 8046,
#  'place': 5569,
#  'hmmmbut': 3646,
#  'give': 3309,
#  'sorry': 6725,
#  'ill': 3827,
#  'later': 4289,
#  'meeting': 4703,
#  'cocksuckers': 2007,
#  'makes': 4598,
#  'better': 1432,
#  'ipads': 3948,
#  'worthless': 8067,
#  'garbage': 3237,
#  'novelty': 5158,
#  'items': 3973,
#  'bad': 1302,
#  'even': 2817,
#  'wanting': 7827,
#  'free': 3138,
#  'entry': 2775,
#  'weekly': 7893,
#  'comp': 2051,
#  'chance': 1853,
#  'win': 7974,
#  'ipod': 3950,
#  'txt': 7539,
#  'pod': 5629,
#  '80182': 720,
#  'std': 6875,
#  'rate': 5923,
#  'tcs': 7153,
#  'apply': 1128,
#  '08452810073': 60,
#  'details': 2422,
#  '18': 352,
#  'way': 7858,
#  'send': 6377,
#  'shades': 6425,
#  'stuff': 6958,
#  'wonderful': 8031,
#  'sounds': 6738,
#  'something': 6698,
#  'testing': 7206,
#  'would': 8071,
#  'sayy': 6297,
#  'hooch': 3687,
#  'walk': 7809,
#  'toaday': 7364,
#  'fell': 2973,
#  'splat': 6788,
#  'grazed': 3410,
#  'knees': 4205,
#  'everything': 2831,
#  'stayed': 6871,
#  'see': 6350,
#  'tomorrow': 7393,
#  'drug': 2625,
#  'able': 841,
#  'eat': 2673,
#  'pa': 5375,
#  'drink': 2610,
#  'milk': 4769,
#  'big': 1445,
#  'difference': 2462,
#  'versus': 7724,
#  'hrs': 3734,
#  'boytoy': 1578,
#  'geeee': 3261,
#  'already': 1023,
#  'woke': 8024,
#  'bed': 1387,
#  'cuddling': 2240,
#  'hopeing': 3696,
#  'pissed': 5563,
#  'remember': 6046,
#  'gone': 3348,
#  'sisters': 6569,
#  'excellent': 2849,
#  'spent': 6775,
#  'years': 8188,
#  'air': 977,
#  'force': 3093,
#  'iraq': 3952,
#  'afghanistan': 936,
#  'stable': 6833,
#  'honest': 3678,
#  'traveling': 7467,
#  'moby': 4842,
#  'pub': 5835,
#  'quizwin': 5891,
#  '100': 255,
#  'high': 3617,
#  'street': 6932,
#  'prize': 5771,
#  'duchess': 2637,
#  'cornwall': 2147,
#  'first': 3030,
#  '82277unsub': 735,
#  'stop': 6909,
#  '150': 313,
#  '008704050406': 0,
#  'sp': 6745,
#  'arrow': 1184,
#  'ever': 2823,
#  'angry': 1069,
#  'misbehaved': 4797,
#  'slap': 6601,
#  'urself': 7659,
#  'bcoz': 1366,
#  'fault': 2948,
#  'im': 3830,
#  'basically': 1340,
#  'good': 3352,
#  'whatever': 7931,
#  'rules': 6220,
#  'talk': 7120,
#  'earlier': 2658,
#  'week': 7889,
#  'start': 6854,
#  'happening': 3513,
#  'showing': 6508,
#  'responsibility': 6106,
#  'yet': 8211,
#  'bend': 1419,
#  'rule': 6219,
#  'tired': 7342,
#  'thia': 7268,
#  'argument': 1163,
#  'movie': 4901,
#  'doesnt': 2539,
#  'inlude': 3902,
#  'previews': 5748,
#  'youre': 8237,
#  'still': 6898,
#  'getting': 3289,
#  'ttyl': 7511,
#  'oi': 5248,
#  'ami': 1041,
#  'parchi': 5415,
#  'na': 4973,
#  'kicchu': 4161,
#  'kaaj': 4110,
#  'korte': 4225,
#  'iccha': 3800,
#  'korche': 4222,
#  'phone': 5527,
#  'ta': 7096,
#  'tul': 7517,
#  'reckon': 5990,
#  'arrange': 1179,
#  'transport': 7464,
#  'cant': 1760,
#  'thanks': 7227,
#  'guai': 3442,
#  'shd': 6445,
#  'haf': 3479,
#  'seen': 6358,
#  'naughty': 5008,
#  'go': 3324,
#  'jogging': 4060,
#  'nah': 4977,
#  'help': 3580,
#  'never': 5050,
#  'iphone': 3949,
#  'anyways': 1108,
#  'gym': 3471,
#  'smiles': 6642,
#  'hope': 3691,
#  'ok': 5252,
#  'babe': 1287,
#  'long': 4455,
#  'dry': 2630,
#  'spell': 6770,
#  'season': 6337,
#  'thank': 7226,
#  'lost': 4477,
#  'havent': 3538,
#  'waitin': 7801,
#  'usual': 7678,
#  'back': 1298,
#  'sch': 6306,
#  'mum': 4939,
#  'since': 6552,
#  'actually': 891,
#  'enjoy': 2759,
#  'rest': 6108,
#  'emailed': 2729,
#  'yifeng': 8215,
#  'part': 5428,
#  'fr': 3127,
#  'wiskey': 8000,
#  'brandy': 1587,
#  'rum': 6221,
#  'gin': 3301,
#  'beer': 1393,
#  'vodka': 7766,
#  'scotch': 6315,
#  'shampain': 6435,
#  'wine': 7981,
#  'kudiyarasu': 4233,
#  'dhina': 2437,
#  'vaazhthukkal': 7689,
#  'thinking': 7276,
#  'face': 2898,
#  'choices': 1934,
#  'toss': 7430,
#  'coin': 2013,
#  'becoz': 1385,
#  'settle': 6406,
#  'question': 5879,
#  'hoping': 3699,
#  'gudni8': 3447,
#  'hotel': 3712,
#  'invitation': 3936,
#  'apologise': 1117,
#  'cali': 1707,
#  'sweet': 7071,
#  'english': 2758,
#  'blokes': 1495,
#  'weddin': 7882,
#  'yesterday': 8210,
#  'sir': 6563,
#  'enjoyed': 2760,
#  'burial': 1669,
#  'mojibiola': 4851,
#  'nokia': 5116,
#  '3510i': 504,
#  'colour': 2029,
#  'deliveredtomorrow': 2386,
#  '300': 481,
#  'minutes': 4793,
#  'camcorder': 1741,
#  '08000930705': 44,
#  'ah': 964,
#  'total': 7432,
#  'video': 7734,
#  'converter': 2128,
#  'download': 2584,
#  'type': 7550,
#  'google': 3368,
#  'search': 6335,
#  'hey': 3608,
#  'lo': 4426,
#  'lesson': 4345,
#  'also': 1029,
#  'cbe': 1821,
#  'pay': 5458,
#  'nothing': 5149,
#  'jus': 4102,
#  'tot': 7431,
#  'ask': 1198,
#  'cos': 2153,
#  'ba': 1283,
#  'gua': 3441,
#  'went': 7914,
#  'mt': 4924,
#  'faber': 2897,
#  'yest': 8209,
#  'mah': 4587,
#  'lor': 4469,
#  'wearing': 7869,
#  'gotta': 3379,
#  'text': 7211,
#  'creepy': 2210,
#  'wont': 8034,
#  'forgot': 3104,
#  'guess': 3451,
#  'phasing': 5520,
#  'fourth': 3122,
#  'dimension': 2473,
#  'tuition': 7516,
#  '330': 500,
#  'hm': 3641,
#  '1120': 278,
#  '1205': 290,
#  'kinda': 4174,
#  'ad': 893,
#  'row': 6195,
#  'wiv': 8008,
#  'walked': 7811,
#  'wanted': 7826,
#  'thanx4': 7233,
#  'cer': 1841,
#  'catch': 1812,
#  'ave': 1258,
#  'time': 7331,
#  'often': 5241,
#  'care': 1775,
#  'soonc': 6716,
#  'bb': 1353,
#  'use': 7664,
#  'wife': 7963,
#  'doctor': 2535,
#  'tick': 7319,
#  'could': 2164,
#  'loneliness': 4453,
#  'pouts': 5697,
#  'stomps': 6905,
#  'feet': 2972,
#  'unlimited': 7611,
#  'limited': 4385,
#  'hate': 3532,
#  'turns': 7526,
#  'shopping': 6484,
#  'annoying': 1080,
#  'look': 4458,
#  'house': 3717,
#  'kate': 4131,
#  'jackson': 4004,
#  'rec': 5973,
#  'center': 1838,
#  '7ish': 703,
#  'right': 6144,
#  'seeing': 6352,
#  'dear': 2337,
#  'brother': 1630,
#  'reached': 5942,
#  'answering': 1089,
#  'maybe': 4675,
#  'youd': 8227,
#  'reboot': 5971,
#  'ym': 8217,
#  'photo': 5533,
#  'great': 3412,
#  'found': 3120,
#  'enc': 2742,
#  'valentines': 7693,
#  'special': 6757,
#  '1000': 256,
#  'quiz': 5889,
#  'partner': 5433,
#  'lifetime': 4366,
#  '83600': 750,
#  '150pmsg': 326,
#  'rcvd': 5937,
#  'custcare08718720201': 2257,
#  'backa': 1299,
#  'necklace': 5023,
#  'token': 7381,
#  'youthats': 8241,
#  'likingbe': 4380,
#  'seeno': 6359,
#  'thatdont': 7236,
#  'mei': 4708,
#  'wait': 7798,
#  'till': 7330,
#  'wan': 7820,
#  'lunch': 4535,
#  'da': 2273,
#  'canteen': 1762,
#  'knowyetunde': 4215,
#  'hasnt': 3529,
#  'money': 4861,
#  'bother': 1546,
#  'involve': 3942,
#  'anything': 1103,
#  'shouldnt': 6498,
#  'imposed': 3846,
#  'said': 6248,
#  'pretty': 5746,
#  'wif': 7962,
#  'hair': 3484,
#  'wat': 7843,
#  'thk': 7282,
#  'cutting': 2268,
#  'quite': 5886,
#  'short': 6489,
#  'leh': 4332,
#  'family': 2924,
#  'booking': 1530,
#  'tour': 7439,
#  'package': 5378,
#  'dunno': 2646,
#  'juz': 4106,
#  'askin': 1201,
#  'card': 1771,
#  '20': 386,
#  'salon': 6258,
#  'sense': 6383,
#  'cut': 2262,
#  'log': 4438,
#  'sdryb8i': 6332,
#  'bored': 1537,
#  'inever': 3882,
#  'thought': 7293,
#  'id': 3806,
#  'tv': 7528,
#  'tell': 7177,
#  'exciting': 2852,
#  'happened': 3511,
#  'gorgeous': 3370,
#  'man': 4607,
#  'squishy': 6823,
#  'mwahs': 4965,
#  'phoned': 5530,
#  'disconnected': 2501,
#  'cool': 2138,
#  'breeze': 1606,
#  'bright': 1609,
#  'sun': 7012,
#  'fresh': 3159,
#  'flower': 3060,
#  'twittering': 7537,
#  'birds': 1460,
#  'waiting': 7802,
#  'yeah': 8185,
#  'guys': 3467,
#  'therere': 7258,
#  'definitely': 2371,
#  'people': 5483,
#  'around': 1176,
#  'guy': 3466,
#  'breathing': 1605,
#  'neck': 5022,
#  'bud': 1650,
#  'anyway': 1107,
#  'half': 3487,
#  'track': 7446,
#  'usf': 7670,
#  'tonight': 7404,
#  'tellmiss': 7179,
#  'weeks': 7894,
#  'putting': 5863,
#  'erm': 2785,
#  'contract': 2123,
#  'ran': 5916,
#  'the4th': 7243,
#  'october': 5222,
#  'morning': 4880,
#  'pouch': 5691,
#  'youve': 8243,
#  'always': 1034,
#  'brainy': 1585,
#  '750': 689,
#  'anytime': 1106,
#  'network': 5046,
#  'mins': 4786,
#  'five': 3034,
#  'pounds': 5694,
#  '08000776320': 42,
#  'delivery': 2387,
#  'xmas': 8153,
#  'iscoming': 3961,
#  'awarded': 1270,
#  'either': 2710,
#  '500': 604,
#  'cd': 1825,
#  'gift': 3296,
#  'vouchers': 7775,
#  'draw': 2598,
#  'music': 4955,
#  '87066': 772,
#  'tnc': 7361,
#  'wwwldewcom1win150ppmx3age16subscription': 8119,
#  'comin': 2042,
#  'dinner': 2480,
#  'aight': 975,
#  'head': 3544,
#  '1st': 376,
#  'no1': 5097,
#  'tone': 7396,
#  'mob': 4831,
#  '8007': 714,
#  'txting': 7544,
#  'mates': 4655,
#  'wwwgetzedcouk': 8115,
#  'pobox': 5614,
#  '36504': 507,
#  'w45wq': 7786,
#  'norm150ptone': 5136,
#  '16': 348,
#  'nope': 5131,
#  'okie': 5258,
#  'lorwe': 4472,
#  'sat': 6279,
#  'friendship': 3171,
#  'game': 3228,
#  'play': 5585,
#  'word': 8040,
#  'march': 4628,
#  'ends': 2748,
#  'may': 4673,
#  'ride': 6143,
#  'okok': 5259,
#  'okthenwhats': 5261,
#  'todays': 7374,
#  'plan': 5575,
#  'uve': 7686,
#  'invited': 3938,
#  'xchat': 8150,
#  'final': 3007,
#  'attempt': 1229,
#  'contact': 2113,
#  'chat': 1875,
#  '86688': 769,
#  'truekdo': 7490,
#  'dis': 2491,
#  'lol': 4448,
#  'mad': 4573,
#  'gave': 3246,
#  'qet': 5871,
#  'ugh': 7557,
#  'leg': 4328,
#  'hurts': 3780,
#  'musta': 4958,
#  'overdid': 5357,
#  'mon': 4857,
#  'boo': 1526,
#  'supposed': 7038,
#  'transfered': 7461,
#  'lastest': 4282,
#  'stereophonics': 6887,
#  'marley': 4636,
#  'dizzee': 2522,
#  'racal': 5896,
#  'libertines': 4357,
#  'strokes': 6942,
#  'nookii': 5128,
#  'games': 3229,
#  'flirt': 3053,
#  'click': 1976,
#  'themob': 7250,
#  'wap': 7829,
#  'bookmark': 1531,
#  '82468': 736,
#  'shower': 6505,
#  'baby': 1291,
#  'hai': 3483,
#  'ana': 1058,
#  'tomarrow': 7388,
#  'ltdecimalgt': 4519,
#  'sathy': 6281,
#  'rto': 6210,
#  'office': 5231,
#  'came': 1742,
#  'roommates': 6187,
#  'allday': 1012,
#  'didnt': 2450,
#  'piss': 5562,
#  'xxx': 8160,
#  'horrible': 3703,
#  'bf': 1437,
#  'hungry': 3767,
#  'waking': 7806,
#  'afternoon': 941,
#  'sry': 6827,
#  'dajst': 2285,
#  'nw': 5198,
#  'pending': 5479,
#  'works': 8052,
#  'height': 3569,
#  'situation': 6575,
#  'throws': 7307,
#  'luv': 4540,
#  'letter': 4349,
#  'gal': 3221,
#  'falls': 2921,
#  'brothers': 1631,
#  'whos': 7953,
#  'gay': 3247,
#  'constant': 2111,
#  'visit': 7755,
#  'kiss': 4181,
#  'sea': 6334,
#  'lays': 4303,
#  'rock': 6170,
#  'envelope': 2778,
#  'paper': 5406,
#  'words': 8043,
#  'favorite': 2954,
#  'oyster': 5373,
#  'sashimi': 6278,
#  'lar': 4274,
#  'dun': 2645,
#  'stomach': 6904,
#  'rumbling': 6222,
#  'multiply': 4938,
#  'numbers': 5188,
#  'independently': 3874,
#  'count': 2167,
#  'decimal': 2355,
#  'division': 2518,
#  'push': 5856,
#  'places': 5573,
#  'showed': 6504,
#  'fyi': 3216,
#  'taking': 7117,
#  'quick': 5883,
#  'epsilon': 2780,
#  'min': 4773,
#  'saying': 6295,
#  'explicitly': 2880,
#  'told': 7383,
#  'nora': 5132,
#  'gonna': 3350,
#  'eh': 2705,
#  'bring': 1615,
#  'god': 3330,
#  'nearby': 5015,
#  'cliffs': 1977,
#  'fixes': 3039,
#  'spelling': 6772,
#  'sometimes': 6702,
#  'gets': 3285,
#  'completely': 2065,
#  'diff': 2459,
#  'figure': 2995,
#  'fri': 3161,
#  'lorgoin': 4471,
#  'drivin': 2617,
#  'den': 2392,
#  'shoppin': 6483,
#  'tt': 7509,
#  'inside': 3912,
#  'officestill': 5233,
#  'filling': 3000,
#  'formsdon': 3113,
#  'wnt': 8020,
#  'buy': 1684,
#  'bmw': 1513,
#  'car': 1770,
#  'urgentlyits': 7652,
#  'vry': 7778,
#  'urgentbut': 7651,
#  'hv': 3785,
#  'shortage': 6490,
#  'lacsthere': 4251,
#  'source': 6741,
#  'arng': 1174,
#  'amt': 1054,
#  'lacsthats': 4250,
#  'prob': 5775,
#  'really': 5961,
#  'dudette': 2639,
#  'missing': 4805,
#  'chikku': 1909,
#  'gud': 3445,
#  'nyt': 5203,
#  'midnight': 4762,
#  'earliest': 2660,
#  'pple700': 5702,
#  '900': 807,
#  'nightsexcellent': 5079,
#  'location': 4431,
#  'breakfast': 1598,
#  'hamper': 3494,
#  'costa': 2156,
#  'del': 2377,
#  'sol': 6682,
#  'holiday': 3664,
#  '5000': 605,
#  'await': 1266,
#  'collection': 2024,
#  '09050090044': 162,
#  'toclaim': 7368,
#  'sae': 6243,
#  'tc': 7150,
#  'pobox334': 5619,
#  'stockport': 6902,
#  'sk38xh': 6583,
#  'costå': 2161,
#  '150pm': 322,
#  'max10mins': 4669,
#  'yo': 8219,
#  'anyone': 1099,
#  'otherwise': 5335,
#  'liquor': 4404,
#  'flaked': 3041,
#  'hold': 3660,
#  'somebody': 6689,
#  'loko': 4447,
#  'coolmob': 2139,
#  'tones': 7397,
#  'ready': 5950,
#  'include': 3861,
#  'crazy': 2199,
#  'frogaxel': 3182,
#  'akonlonely': 988,
#  'black': 1471,
#  'eyeddont': 2892,
#  'info': 3887,
#  'kent': 4147,
#  'vale': 7691,
#  'ar': 1148,
#  'water': 7849,
#  'logging': 4440,
#  'desert': 2410,
#  'geoenvironmental': 3276,
#  'implications': 3843,
#  'lect': 4323,
#  'finish': 3018,
#  'talking': 7123,
#  'boy': 1574,
#  'offerthe': 5230,
#  'nokia6650': 5119,
#  'txtauction': 7541,
#  '81151': 729,
#  '4tctxt': 593,
#  '150pmtmsg': 330,
#  'th': 7223,
#  'birthday': 1464,
#  'loving': 4503,
#  'gopalettan': 3369,
#  'planning': 5581,
#  'small': 6629,
#  'participate': 5429,
#  'welcome': 7905,
#  'admin': 906,
#  'team': 7163,
#  'fighting': 2992,
#  'world': 8053,
#  'lose': 4473,
#  'bt': 1643,
#  'fightng': 2993,
#  'some1': 6688,
#  'close': 1982,
#  'dificult': 2467,
#  'durban': 2648,
#  'might': 4764,
#  'accidant': 861,
#  'tookplace': 7409,
#  'somewhere': 6705,
#  'ghodbandar': 3292,
#  'rd': 5938,
#  'traffic': 7450,
#  'moves': 4900,
#  'slovely': 6623,
#  'slip': 6617,
#  'worry': 8060,
#  'kitty': 4187,
#  'shaved': 6443,
#  'natural': 5005,
#  'noi': 5111,
#  'rumour': 6224,
#  'apartment': 1112,
#  'chennai': 1897,
#  'done': 2561,
#  'england': 2757,
#  'official': 5235,
#  'poly': 5640,
#  'ringtone': 6153,
#  'flag': 3040,
#  'yer': 8195,
#  '84199': 756,
#  'optout': 5310,
#  'eng': 2752,
#  'box39822': 1566,
#  'w111wx': 7781,
#  'ki': 4160,
#  'kvb': 4235,
#  'acc': 855,
#  'licks': 4360,
#  'tootsie': 7415,
#  'pop': 5658,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8283 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.827 / Accuracy: 0.978
